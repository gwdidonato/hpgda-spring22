# %%
# Download the repository
# !git clone https://github.com/AlbertoParravicini/high-performance-graph-analytics-2021.git
# Out:
# Cloning into 'high-performance-graph-analytics-2021'...
# remote: Enumerating objects: 57, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 57 (delta 24), reused 40 (delta 16), pack-reused 0
# Unpacking objects: 100% (57/57), done.

# %%
# Install CUDA
# !wget https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64/cuda-ubuntu1804.pin
# !sudo mv cuda-ubuntu1804.pin /etc/apt/preferences.d/cuda-repository-pin-600
# !wget https://developer.download.nvidia.com/compute/cuda/11.5.0/local_installers/cuda-repo-ubuntu1804-11-5-local_11.5.0-495.29.05-1_amd64.deb
# !sudo dpkg -i cuda-repo-ubuntu1804-11-5-local_11.5.0-495.29.05-1_amd64.deb
# !sudo apt-key add /var/cuda-repo-ubuntu1804-11-5-local/7fa2af80.pub
# !sudo apt-get update
# !sudo apt-get -y install cuda
# Out:
# --2021-11-14 13:41:41--  https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64/cuda-ubuntu1804.pin
# Resolving developer.download.nvidia.com (developer.download.nvidia.com)... 152.199.20.126
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|152.199.20.126|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 190 [application/octet-stream]
# Saving to: ‘cuda-ubuntu1804.pin’
#
# cuda-ubuntu1804.pin 100%[===================>]     190  --.-KB/s    in 0s
#
# 2021-11-14 13:41:41 (10.0 MB/s) - ‘cuda-ubuntu1804.pin’ saved [190/190]
#
# --2021-11-14 13:41:41--  https://developer.download.nvidia.com/compute/cuda/11.5.0/local_installers/cuda-repo-ubuntu1804-11-5-local_11.5.0-495.29.05-1_amd64.deb
# Resolving developer.download.nvidia.com (developer.download.nvidia.com)... 152.199.20.126
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|152.199.20.126|:443... connected.
# ...

# %%
# %cd high-performance-graph-analytics-2021/cuda  
# !git pull                                       # Ensure right data are available
# !git checkout kepler                            # Branch with code runnable on K80
import os                                       # Find nvcc on command line
os.environ['PATH'] += ':/usr/local/cuda/bin'
# !make                                           # Build the code
# Out:
# [Errno 2] No such file or directory: 'high-performance-graph-analytics-2021/cuda'
# /content/high-performance-graph-analytics-2021/cuda
# remote: Enumerating objects: 40, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 25 (delta 13), reused 25 (delta 13), pack-reused 0
# Unpacking objects: 100% (25/25), done.
# From https://github.com/AlbertoParravicini/high-performance-graph-analytics-2021
#    426a334..34abb36  master     -> origin/master
#  * [new branch]      kepler     -> origin/kepler
# Updating 426a334..34abb36
# Fast-forward
#  cuda/README.md                           |  2 ++
#  cuda/benchmarks/matrix_multiplication.cu | 33 ++++++++++++++++++++++++++++++++
#  cuda/benchmarks/vector_sum.cu            |  3 ++-
#  cuda/run.sh                              |  9 +++++++++
#  4 files changed, 46 insertions(+), 1 deletion(-)
#  create mode 100644 cuda/run.sh
# ...

# %%
# !chmod 755 run.sh # Ensure run.sh is executable
# !./run.sh         # Run the code!
# Out:
# ------------------------------
# - running vec
# - num executions=30
# - iterations to skip=3
# - N=100000000
# - implementation number to use (where applicable)=1
# - block size (1D)=64
# - num blocks (1D, where applicable)=64
# - nvprof support=0
# - do cpu validation=1
# ------------------------------
# allocation time=126 ms
# initialization time=247 ms
#
# -- iter=0
#   reset=59.487 ms
#   pure GPU execution(0)=28.737 ms, 13.9193 GB/s
#   GPU execution(0)=28.929 ms
#   GPU result=18.998077
# exec time CPU=121.624 ms
# result error! GPU=18.9981, CPU=15.4037
#
# -- iter=1
#   reset=56.973 ms
#   pure GPU execution(1)=28.765 ms, 13.9058 GB/s
#   GPU execution(1)=28.882 ms
#   GPU result=18.998077
# exec time CPU=120.394 ms
# result error! GPU=18.9981, CPU=15.4037
#
# -- iter=2
#   reset=59.795 ms
#   pure GPU execution(2)=28.77 ms, 13.9034 GB/s
#   GPU execution(2)=28.884 ms
#   GPU result=18.998077
# exec time CPU=118.761 ms
# result error! GPU=18.9981, CPU=15.4037
#
# -- iter=3
# ...
